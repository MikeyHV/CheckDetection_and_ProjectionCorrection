# %%
# !pip install pyyaml==5.1

import torch
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Install detectron2 that matches the above pytorch version
# See https://detectron2.readthedocs.io/tutorials/install.html for instructions
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/$CUDA_VERSION/torch$TORCH_VERSION/index.html
# If there is not yet a detectron2 release that matches the given torch + CUDA version, you need to install a different pytorch.

# exit(0)  # After installation, you may need to "restart runtime" in Colab. This line can also restart runtime

import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
import imutils
# import some common libraries
import numpy as np
import os, json, cv2, random
import cv2 as cv
import matplotlib.pyplot as plt

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
# Out:
# Requirement already satisfied: pyyaml==5.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (5.1)
# torch:  1.11 ; cuda:  1.11.0
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/1.11.0/torch1.11/index.html
# Requirement already satisfied: detectron2 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (0.6)
# Requirement already satisfied: Pillow>=7.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from detectron2) (9.0.1)
# Requirement already satisfied: pydot in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/pydot-1.4.2-py3.9.egg (from detectron2) (1.4.2)
# Requirement already satisfied: yacs>=0.1.8 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/yacs-0.1.8-py3.9.egg (from detectron2) (0.1.8)
# Requirement already satisfied: cloudpickle in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from detectron2) (2.0.0)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/iopath-0.1.9-py3.9.egg (from detectron2) (0.1.9)
# Requirement already satisfied: termcolor>=1.1 in /Users/me/.local/lib/python3.9/site-packages (from detectron2) (1.1.0)
# Requirement already satisfied: matplotlib in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from detectron2) (3.4.3)
# Requirement already satisfied: future in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from detectron2) (0.18.2)
# Requirement already satisfied: tqdm>4.29.0 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from detectron2) (4.62.1)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/fvcore-0.1.5.post20220414-py3.9.egg (from detectron2) (0.1.5.post20220414)
# Requirement already satisfied: scipy>1.5.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from detectron2) (1.7.3)
# Requirement already satisfied: hydra-core>=1.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/hydra_core-1.2.0.dev5-py3.9.egg (from detectron2) (1.2.0.dev5)
# Requirement already satisfied: pycocotools>=2.0.2 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from detectron2) (2.0.4)
# Requirement already satisfied: tensorboard in /Users/me/.local/lib/python3.9/site-packages (from detectron2) (2.8.0)
# Requirement already satisfied: black==21.4b2 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/black-21.4b2-py3.9.egg (from detectron2) (21.4b2)
# Requirement already satisfied: omegaconf>=2.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/omegaconf-2.2.0-py3.9.egg (from detectron2) (2.2.0)
# Requirement already satisfied: tabulate in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/tabulate-0.8.9-py3.9.egg (from detectron2) (0.8.9)
# Requirement already satisfied: click>=7.1.2 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from black==21.4b2->detectron2) (8.0.4)
# Requirement already satisfied: appdirs in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from black==21.4b2->detectron2) (1.4.4)
# Requirement already satisfied: toml>=0.10.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/toml-0.10.2-py3.9.egg (from black==21.4b2->detectron2) (0.10.2)
# Requirement already satisfied: regex>=2020.1.8 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from black==21.4b2->detectron2) (2022.3.15)
# Requirement already satisfied: pathspec<1,>=0.8.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/pathspec-0.9.0-py3.9.egg (from black==21.4b2->detectron2) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/mypy_extensions-0.4.3-py3.9.egg (from black==21.4b2->detectron2) (0.4.3)
# Requirement already satisfied: numpy in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (1.21.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (5.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/antlr4_python3_runtime-4.8-py3.9.egg (from hydra-core>=1.1->detectron2) (4.8)
# Requirement already satisfied: packaging in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from hydra-core>=1.1->detectron2) (21.3)
# Requirement already satisfied: portalocker in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages/portalocker-2.4.0-py3.9.egg (from iopath<0.1.10,>=0.1.7->detectron2) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from matplotlib->detectron2) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from matplotlib->detectron2) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from matplotlib->detectron2) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from matplotlib->detectron2) (1.3.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from tensorboard->detectron2) (61.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from tensorboard->detectron2) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (2.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (2.0.3)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (1.43.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from tensorboard->detectron2) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (3.3.6)
# Requirement already satisfied: protobuf>=3.6.0 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (3.19.4)
# Requirement already satisfied: absl-py>=0.4 in /Users/me/.local/lib/python3.9/site-packages (from tensorboard->detectron2) (1.0.0)
# Requirement already satisfied: six in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from absl-py>=0.4->tensorboard->detectron2) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/me/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/me/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/me/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/me/.local/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->detectron2) (4.11.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.0.7)
# Requirement already satisfied: zipp>=0.5 in /Users/me/anaconda3/envs/collegeF21/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->detectron2) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/me/.local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/me/.local/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2) (3.2.0)

# %%
import pytesseract
import argparse
import imutils
import cv2
import cv2 as cv
import re
import numpy as np
import math

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
def pltshow(imgzz):
    plt.imshow(cv2.cvtColor(imgzz, cv2.COLOR_BGR2RGB))
    
def eqhist(img):
    return cv2.equalizeHist(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))

def getCanPipe(image, eqHist = False, blur = True, ):
    if eqHist:
        gray = eqhist(image)
    else:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    if blur:
        blurred = cv2.GaussianBlur(gray, (5, 5,), 0)
    else:
        blurred = gray
    edged = cv2.Canny(blurred, 100, 300)
    return edged

def sortCorners(corners):
    c = []
    idx = 0
    for i in corners.tolist():
        c.append(i[0])
        idx+=1
    c = sorted(c, key=lambda x:x[1])
    topones = [c[0], c[1]]
    bottomones = [c[2], c[3]]
    topones = sorted(topones, key = lambda x:x[0])
    topleft = topones[0]
    topright = topones[1]

    botones = sorted(bottomones, key = lambda x:x[0])
    bottomleft = botones[0]
    bottomright = botones[1]
    cornersz = [topleft, topright, bottomleft, bottomright]
    return cornersz

def getRect(edged):
    cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

    receiptCnt = None
    for c in cnts:
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * peri, True)
        if len(approx) == 4:
            receiptCnt = approx
            # print(receiptCnt)
            break
    if receiptCnt is None:
        raise Exception(("No outline, oof"))
    return receiptCnt

def drawRect(image, rect):
    output = image.copy()
    cv2.drawContours(output, [rect], -1, (0, 255, 0), 2)
    pltshow(output)

def histeq(rgb_img):
    ycrcb_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2YCrCb)
    ycrcb_img[:, :, 0] = cv2.equalizeHist(ycrcb_img[:, :, 0])
    return cv2.cvtColor(ycrcb_img, cv2.COLOR_YCrCb2BGR)

def subtractMaskFromImg(img, mask1):
    mask2 = cv2.bitwise_not(mask1)
    return cv2.bitwise_and(img, img, mask = mask2)

def getMaskFromImg(img, mask):
    return cv2.bitwise_and(img, img, mask = mask)

# %% [markdown]
# # Working shiz

# %%
plt.rcParams["figure.figsize"] = (15,15)

# %%
# imgs = [histeq(img) for img in imgs]
imgpath = "samples/check3.jpg"

orig = cv2.imread(imgpath)
image = orig.copy()
image = imutils.resize(image, width = 500) ## if the image does not have any humans, resize, else dont
ratio = orig.shape[1] / float(image.shape[1])

imagec = histeq(image)

cfg = get_cfg()
cfg.MODEL.DEVICE='cpu'
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)

outputs = predictor(imagec)

v = Visualizer(image[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
pltshow(out.get_image()[:, :, ::-1])

# %%
peopleMasks = []
bookMasks = []
isABookMask = False
temp = outputs["instances"]

if 73 in temp.pred_classes and 0 not in temp.pred_classes:
    print("Skip me, go straight to the next step")
elif 73 in temp.pred_classes and 0 in temp.pred_classes:  # assuming only one book in the image
    bookmask = np.array(temp.pred_masks[list(temp.pred_classes).index(73)])
    indices = bookmask.astype(np.uint8)  #convert to an unsigned byte
    indices*=255
    kernel = np.ones((1,1), np.uint8)
    img_dilation = cv2.dilate(indices, kernel, iterations=20)
    bookMask = getMaskFromImg(imagec, img_dilation)
    isABookMask = True
else:  # lots of people in the img
    cntr = 0
    for i in list(temp.pred_classes):
        if i == 0 or i == 27 or i == 58:
            pplMask = np.array(temp.pred_masks[cntr])
            indices = pplMask.astype(np.uint8)
            indices*=255
            kernel = np.ones((3,3), np.uint8)
            img_dilation = cv2.dilate(indices, kernel, iterations=1)
            imagec = subtractMaskFromImg(imagec, img_dilation)
        cntr += 1
pltshow(bookMask)

# %%
def fitScreenToRect(image, corners):
    rows,cols,ch = image.shape
    H, W = image.shape[:2]
    pts1 = np.float32(sortCorners(corners))
    pts2 = np.float32([[0,0],[W,0],[0,H],[W,H]])
    M = cv2.getPerspectiveTransform(pts1,pts2)

    dst = cv2.warpPerspective(image,M,(W,H))
    # dst = cv2.warpPerspective(image,M,(W + (W * 0.5),H))
    return dst
dst = fitScreenToRect(image, corners)
plt.subplot(121),plt.imshow(image),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 11>()
#       9     # dst = cv2.warpPerspective(image,M,(W + (W * 0.5),H))
#      10     return dst
# ---> 11 dst = fitScreenToRect(image, corners)
#      12 plt.subplot(121),plt.imshow(image),plt.title('Input')
#      13 plt.subplot(122),plt.imshow(dst),plt.title('Output')
#
# NameError: name 'corners' is not defined

# %%
def correctPerspectiveAndOrientationGivenCheck(dst):
    smallCorners = getRect(getCanPipe(dst, eqHist=True))
    closestToBottomRight = sortCorners(smallCorners)[3]  # this is what we want to set as the top left
    H, W = dst.shape[:2]
    horLine = W/2
    verLine = H/2
    if closestToBottomRight[0] < horLine and closestToBottomRight[1] < verLine:  # top left
        dst = cv2.rotate(dst, cv2.ROTATE_90_CLOCKWISE)
    elif closestToBottomRight[0] < horLine and closestToBottomRight[1] > verLine:  # bottom left
        dst = cv2.rotate(dst, cv2.ROTATE_90_CLOCKWISE)
        dst = cv2.rotate(dst, cv2.ROTATE_90_CLOCKWISE)
    elif closestToBottomRight[0] > horLine and closestToBottomRight[1] > verLine:  # bottom right
        dst = cv2.rotate(dst, cv2.ROTATE_90_CLOCKWISE)
        dst = cv2.rotate(dst, cv2.ROTATE_90_CLOCKWISE)
        dst = cv2.rotate(dst, cv2.ROTATE_90_CLOCKWISE)
    return dst, smallCorners
finImg, smallBox = correctPerspectiveAndOrientationGivenCheck(dst)
pltshow(finImg)

# %%
zz = fitScreenToRect(finImg, smallBox)
pltshow(zz)

# %%
img2 = getCanPipe(dst, eqHist = True)
pltshow(img2)
zz = getRect(img2)
drawRect(dst, zz)

# %%
pltshow(eqhist(dst))
